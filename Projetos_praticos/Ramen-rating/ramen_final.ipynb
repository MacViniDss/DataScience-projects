# %% [markdown]
# Neste projeto, analisaremos o dataset **Ramen Ratings**, disponível no Kaggle, que contém milhares de avaliações de diferentes marcas e estilos de ramen ao redor do mundo.
#
# **Objetivos principais:**
# - Investigar quais países produzem os ramens mais bem avaliados;
# - Identificar as marcas mais consistentes em qualidade;
# - Explorar padrões entre estilo (cup, bowl, pack) e nota;
# - Criar visualizações que contem a história dos dados.

# %%
import pandas as pd

df = pd.read_csv('/home/marcus-vinicius/Desktop/Python/Kaggle/ramen-ratings.csv')

# %% [markdown]
# Conhecendo meus dados:

# %%
df.head()
# Out:
#    Review #           Brand  \
# 0      2580       New Touch
# 1      2579        Just Way
# 2      2578          Nissin
# 3      2577         Wei Lih
# 4      2576  Ching's Secret
#
#                                              Variety Style Country Stars  \
# 0                          T's Restaurant Tantanmen    Cup   Japan  3.75
# 1  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack  Taiwan     1
# 2                      Cup Noodles Chicken Vegetable   Cup     USA  2.25
# 3                      GGE Ramen Snack Tomato Flavor  Pack  Taiwan  2.75
# 4                                    Singapore Curry  Pack   India  3.75
#
#   Top Ten
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Review #  2580 non-null   int64
#  1   Brand     2580 non-null   object
#  2   Variety   2580 non-null   object
#  3   Style     2578 non-null   object
#  4   Country   2580 non-null   object
#  5   Stars     2580 non-null   object
#  6   Top Ten   41 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 141.2+ KB

# %%
# A coluna 'Star' é float porem está como object. Aqui mudamos isso!
df['Stars'] = pd.to_numeric(df['Stars'], errors= 'coerce')
# Deixando o nome das colunas, valores str uniformes
df.columns = df.columns.str.lower().str.replace(' ','_')

categorical_columns = list(df.dtypes[df.dtypes == 'object'].index)
# Aqui faço uma limpeza nas str
for c in categorical_columns:
    df[c] = df[c].str.lower().str.replace(' ', '_')
    df[c] = df[c].str.lower().str.replace('-', '_')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   review_#  2580 non-null   int64
#  1   brand     2580 non-null   object
#  2   variety   2580 non-null   object
#  3   style     2578 non-null   object
#  4   country   2580 non-null   object
#  5   stars     2577 non-null   float64
#  6   top_ten   41 non-null     object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 141.2+ KB

# %%
df.head()
# Out:
#    review_#           brand  \
# 0      2580       new_touch
# 1      2579        just_way
# 2      2578          nissin
# 3      2577         wei_lih
# 4      2576  ching's_secret
#
#                                              variety style country  stars  \
# 0                          t's_restaurant_tantanmen_   cup   japan   3.75
# 1  noodles_spicy_hot_sesame_spicy_hot_sesame_guan...  pack  taiwan   1.00
# 2                      cup_noodles_chicken_vegetable   cup     usa   2.25
# 3                      gge_ramen_snack_tomato_flavor  pack  taiwan   2.75
# 4                                    singapore_curry  pack   india   3.75
#
#   top_ten
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
# Procurando valores NaN/vazios e fazendo a limpeza
df.isnull().sum()
# Out:
# review_#       0
# brand          0
# variety        0
# style          2
# country        0
# stars          3
# top_ten     2539
# dtype: int64

# %%
df[df['style'].isnull()]
# Out:
#       review_#   brand            variety style country  stars top_ten
# 2152       428  kamfen     e_menm_chicken   NaN   china   3.75     NaN
# 2442       138    unif  100_furong_shrimp   NaN  taiwan   3.00     NaN

# %% [markdown]
# Limpeza dos dados:

# %%
# A coluna 'style' não tem muita relevancia nesses casos, podemos assim excluir respectivas linhas(2152 e 2442)
df.drop(2152, axis = 0, inplace = True)
df.drop(2442, axis = 0, inplace = True)

# %%
df[df['stars'].isnull()]
# Out:
#      review_#          brand                                variety style  \
# 32       2548         ottogi  plain_instant_noodle_no_soup_included  pack
# 122      2458  samyang_foods                             sari_ramen  pack
# 993      1587       mi_e_zee                          plain_noodles  pack
#
#          country  stars top_ten
# 32   south_korea    NaN     NaN
# 122  south_korea    NaN     NaN
# 993     malaysia    NaN     NaN

# %%
# Conseguimos dessa maneira adicionar o valor mediano 'stars' onde falta com as respectiva marca e país
row_1 = df.loc[(df['brand']=='ottogi') & (df['country']=='south_korea')]
df.loc[32,'stars'] = round(row_1.stars.mean(),2)
df.loc[32]
# Out:
# review_#                                     2548
# brand                                      ottogi
# variety     plain_instant_noodle_no_soup_included
# style                                        pack
# country                               south_korea
# stars                                        3.34
# top_ten                                       NaN
# Name: 32, dtype: object

# %%
# So repetir o processo e teremos todos os valores 'stars' preenchidos
row_2 = df.loc[(df['brand']=='samyang_foods') & (df['country']=='south_korea')]
df.loc[122,'stars'] = round(row_2.stars.mean(),2)
row_3 = df.loc[(df['brand']=='mi_e_zee') & (df['country']=='malaysia')]
df.loc[993,'stars'] = round(row_3.stars.mean(),2)
df.isnull().sum()
# Out:
# review_#       0
# brand          0
# variety        0
# style          0
# country        0
# stars          0
# top_ten     2537
# dtype: int64

# %%
df['top_ten'].fillna(0, inplace=True)
# Valores incoerentes/incompletos mesmo tendo preenchido os NaN com 0
df[df['top_ten'] != 0]
# Out:
#       review_#             brand  \
# 616       1964              mama
# 633       1947       prima_taste
# 655       1925             prima
# 673       1907       prima_taste
# 752       1828     tseng_noodles
# 891       1689      wugudaochang
# 942       1638  a_sha_dry_noodle
# 963       1617           mykuali
# 995       1585            carjen
# 1059      1521          maruchan
# 1072      1508             mamee
# 1080      1500           mykuali
# 1109      1471              mama
# 1114      1466              mama
# 1230      1350             mamee
# 1250      1330   sapporo_ichiban
# 1272      1308          nongshim
# 1278      1302              mama
# 1309      1271       prima_taste
# 1382      1198     samyang_foods
# 1397      1183             paldo
# 1493      1087           mykuali
# 1588       992       prima_taste
# 1589       991       prima_taste
# 1646       934          nongshim
# 1670       910             paldo
# 1757       823             paldo
# 1846       734           indomie
# 1865       715           indomie
# 1972       608              koka
# 2002       578          nongshim
# 2146       434         mi_sedaap
# 2188       392            nissin
# 2189       391             myojo
# 2248       332          nongshim
# 2295       285              doll
# 2475       105           indomie
# 2533        47           indomie
# 2535        45           indomie
# 2549        31             myojo
# 2567        13   sapporo_ichiban
#
#                                                 variety style      country  \
# 616                instant_noodles_coconut_milk_flavour  pack      myanmar
# 633                  singapore_laksa_wholegrain_la_mian  pack    singapore
# 655                   juzz's_mee_creamy_chicken_flavour  pack    singapore
# 673                  singapore_curry_wholegrain_la_mian  pack    singapore
# 752                scallion_with_sichuan_pepper__flavor  pack       taiwan
# 891     tomato_beef_brisket_flavor_purple_potato_noodle  pack        china
# 942   veggie_noodle_tomato_noodle_with_vine_ripened_...  pack       taiwan
# 963    penang_hokkien_prawn_noodle_(new_improved_taste)  pack     malaysia
# 995                                  nyonya_curry_laksa  pack     malaysia
# 1059                           gotsumori_sauce_yakisoba  tray        japan
# 1072               chef_gold_recipe_mi_kari_seribu_rasa  pack     malaysia
# 1080                    penang_red_tom_yum_goong_noodle  pack     malaysia
# 1109  instant_noodles_shrimp_creamy_tom_yum_flavour_...  pack     thailand
# 1114  oriental_style_instant_noodles_green_curry_fla...  pack     thailand
# 1230                           chef_curry_laksa_flavour  pack     malaysia
# 1250                     otafuku_okonomi_sauce_yakisoba  tray        japan
# 1272                            soon_veggie_noodle_soup  pack  south_korea
# 1278     instant_noodles_yentafo_tom_yum_mohfai_flavour  pack     thailand
# 1309                      singapore_chilli_crab_la_mian  pack    singapore
# 1382                    maesaengyitangmyun_baked_noodle  pack  south_korea
# 1397                                      cheese_noodle  pack  south_korea
# 1493                          penang_white_curry_noodle  pack     malaysia
# 1588                            singapore_laksa_la_mian  pack    singapore
# 1589                            singapore_curry_la_mian  pack    singapore
# 1646                  jinjja_jinjja_flamin'_hot_&_nutty  pack          usa
# 1670                                       namja_ramyun  bowl  south_korea
# 1757                              kokomen_spicy_chicken  pack  south_korea
# 1846         mi_goreng_rasa_ayam_panggang_jumbo_(local)  pack    indonesia
# 1865                         mi_goreng_rendang_(import)  pack    indonesia
# 1972                                 spicy_black_pepper  pack    singapore
# 2002                                  shin_ramyun_black  pack  south_korea
# 2146                                       kari_spesial  pack    indonesia
# 2188                           yakisoba_noodles_karashi  tray        japan
# 2189                    hyoubanya_no_chukasoba_oriental  pack        japan
# 2248                          champong_oriental_noodles   cup  south_korea
# 2295                                 artificial_chicken  pack    hong_kong
# 2475                         special_fried_curly_noodle  pack    indonesia
# 2533                   mi_goreng_jumbo_barbecue_chicken  pack    indonesia
# 2535                                     mi_goreng_sate  pack    indonesia
# 2549                                 ippeichan_yakisoba  tray        japan
# 2567                                          chow_mein  pack        japan
#
#       stars   top_ten
# 616    5.00  2016_#10
# 633    5.00   2016_#1
# 655    5.00   2016_#8
# 673    5.00   2016_#5
# 752    5.00   2016_#9
# 891    5.00   2016_#7
# 942    5.00  2015_#10
# 963    5.00   2015_#7
# 995    5.00   2015_#4
# 1059   5.00   2015_#9
# 1072   5.00   2015_#6
# 1080   5.00   2015_#1
# 1109   5.00  2013_#10
# 1114   5.00   2015_#8
# 1230   5.00   2014_#7
# 1250   5.00   2014_#4
# 1272   5.00   2014_#9
# 1278   5.00  2014_#10
# 1309   5.00   2014_#8
# 1382   5.00   2014_#5
# 1397   5.00   2014_#6
# 1493   5.00   2014_#1
# 1588   5.00   2013_#1
# 1589   5.00   2013_#2
# 1646   5.00   2013_#4
# 1670   4.25        \n
# 1757   5.00   2013_#9
# 1846   5.00        \n
# 1865   5.00   2013_#3
# 1972   5.00  2012_#10
# 2002   4.75   2012_#7
# 2146   4.50   2012_#5
# 2188   5.00   2012_#3
# 2189   4.25   2012_#6
# 2248   3.75        \n
# 2295   4.50   2012_#9
# 2475   5.00   2012_#1
# 2533   5.00   2012_#2
# 2535   5.00        \n
# 2549   4.00   2013_#6
# 2567   5.00   2012_#4

# %%
top_ten_n= df[df['top_ten'] == '\n']
for i in top_ten_n.index:
    df.loc[i,'top_ten']=0

df[df['top_ten'] != 0]
# Out:
#       review_#             brand  \
# 616       1964              mama
# 633       1947       prima_taste
# 655       1925             prima
# 673       1907       prima_taste
# 752       1828     tseng_noodles
# 891       1689      wugudaochang
# 942       1638  a_sha_dry_noodle
# 963       1617           mykuali
# 995       1585            carjen
# 1059      1521          maruchan
# 1072      1508             mamee
# 1080      1500           mykuali
# 1109      1471              mama
# 1114      1466              mama
# 1230      1350             mamee
# 1250      1330   sapporo_ichiban
# 1272      1308          nongshim
# 1278      1302              mama
# 1309      1271       prima_taste
# 1382      1198     samyang_foods
# 1397      1183             paldo
# 1493      1087           mykuali
# 1588       992       prima_taste
# 1589       991       prima_taste
# 1646       934          nongshim
# 1757       823             paldo
# 1865       715           indomie
# 1972       608              koka
# 2002       578          nongshim
# 2146       434         mi_sedaap
# 2188       392            nissin
# 2189       391             myojo
# 2295       285              doll
# 2475       105           indomie
# 2533        47           indomie
# 2549        31             myojo
# 2567        13   sapporo_ichiban
#
#                                                 variety style      country  \
# 616                instant_noodles_coconut_milk_flavour  pack      myanmar
# 633                  singapore_laksa_wholegrain_la_mian  pack    singapore
# 655                   juzz's_mee_creamy_chicken_flavour  pack    singapore
# 673                  singapore_curry_wholegrain_la_mian  pack    singapore
# 752                scallion_with_sichuan_pepper__flavor  pack       taiwan
# 891     tomato_beef_brisket_flavor_purple_potato_noodle  pack        china
# 942   veggie_noodle_tomato_noodle_with_vine_ripened_...  pack       taiwan
# 963    penang_hokkien_prawn_noodle_(new_improved_taste)  pack     malaysia
# 995                                  nyonya_curry_laksa  pack     malaysia
# 1059                           gotsumori_sauce_yakisoba  tray        japan
# 1072               chef_gold_recipe_mi_kari_seribu_rasa  pack     malaysia
# 1080                    penang_red_tom_yum_goong_noodle  pack     malaysia
# 1109  instant_noodles_shrimp_creamy_tom_yum_flavour_...  pack     thailand
# 1114  oriental_style_instant_noodles_green_curry_fla...  pack     thailand
# 1230                           chef_curry_laksa_flavour  pack     malaysia
# 1250                     otafuku_okonomi_sauce_yakisoba  tray        japan
# 1272                            soon_veggie_noodle_soup  pack  south_korea
# 1278     instant_noodles_yentafo_tom_yum_mohfai_flavour  pack     thailand
# 1309                      singapore_chilli_crab_la_mian  pack    singapore
# 1382                    maesaengyitangmyun_baked_noodle  pack  south_korea
# 1397                                      cheese_noodle  pack  south_korea
# 1493                          penang_white_curry_noodle  pack     malaysia
# 1588                            singapore_laksa_la_mian  pack    singapore
# 1589                            singapore_curry_la_mian  pack    singapore
# 1646                  jinjja_jinjja_flamin'_hot_&_nutty  pack          usa
# 1757                              kokomen_spicy_chicken  pack  south_korea
# 1865                         mi_goreng_rendang_(import)  pack    indonesia
# 1972                                 spicy_black_pepper  pack    singapore
# 2002                                  shin_ramyun_black  pack  south_korea
# 2146                                       kari_spesial  pack    indonesia
# 2188                           yakisoba_noodles_karashi  tray        japan
# 2189                    hyoubanya_no_chukasoba_oriental  pack        japan
# 2295                                 artificial_chicken  pack    hong_kong
# 2475                         special_fried_curly_noodle  pack    indonesia
# 2533                   mi_goreng_jumbo_barbecue_chicken  pack    indonesia
# 2549                                 ippeichan_yakisoba  tray        japan
# 2567                                          chow_mein  pack        japan
#
#       stars   top_ten
# 616    5.00  2016_#10
# 633    5.00   2016_#1
# 655    5.00   2016_#8
# 673    5.00   2016_#5
# 752    5.00   2016_#9
# 891    5.00   2016_#7
# 942    5.00  2015_#10
# 963    5.00   2015_#7
# 995    5.00   2015_#4
# 1059   5.00   2015_#9
# 1072   5.00   2015_#6
# 1080   5.00   2015_#1
# 1109   5.00  2013_#10
# 1114   5.00   2015_#8
# 1230   5.00   2014_#7
# 1250   5.00   2014_#4
# 1272   5.00   2014_#9
# 1278   5.00  2014_#10
# 1309   5.00   2014_#8
# 1382   5.00   2014_#5
# 1397   5.00   2014_#6
# 1493   5.00   2014_#1
# 1588   5.00   2013_#1
# 1589   5.00   2013_#2
# 1646   5.00   2013_#4
# 1757   5.00   2013_#9
# 1865   5.00   2013_#3
# 1972   5.00  2012_#10
# 2002   4.75   2012_#7
# 2146   4.50   2012_#5
# 2188   5.00   2012_#3
# 2189   4.25   2012_#6
# 2295   4.50   2012_#9
# 2475   5.00   2012_#1
# 2533   5.00   2012_#2
# 2549   4.00   2013_#6
# 2567   5.00   2012_#4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2578 entries, 0 to 2579
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   review_#  2578 non-null   int64
#  1   brand     2578 non-null   object
#  2   variety   2578 non-null   object
#  3   style     2578 non-null   object
#  4   country   2578 non-null   object
#  5   stars     2578 non-null   float64
#  6   top_ten   2578 non-null   object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 225.7+ KB

# %% [markdown]
# **Resumo da limpeza:**
# - Colunas e valores str padronizadas para minúsculas e espaços trocados com '_';
# - Valores não numéricos em `stars` convertidos para a media de cada país e marca da respectiva linha;
# - Valores NaN em `style` foram considerados irrelevades para o trabalho e assim excluidas as respectivas linhas;
# - Valores NaN em `top_ten` preenchidos com 0 e ainda substituido os '\n' por 0;
# - Dataset final com 2578 linhas e 7 colunas.

# %% [markdown]
# Visualização e analise:

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Popularidade de Ramens pelo mundo
v = df.country.value_counts()
v = v.sort_values(ascending= True)
fig, ax = plt.subplots(figsize= (12,8))
v.plot(kind='barh')
plt.show()
plt.savefig('popularidade_ramen.png')

# %%
# Países com mais avaliações
top_countries = df['country'].value_counts().head(10)
sns.barplot(x= top_countries.values, y= top_countries.index)
plt.title("Top 10 países com mais avaliações de ramen")
plt.xlabel("Quantidade de avaliações")
plt.ylabel("País")
plt.show()

# %%
# Países com melhor avaliação média de ramen
country_mean_score = df.groupby('country')['stars'].mean().sort_values(ascending=False).head(10)
sns.barplot(x=country_mean_score.values, y=country_mean_score.index)
plt.title("Top 10 países com melhor avaliação de ramen")
plt.xlabel("Média de avaliação")
plt.ylabel("País")
plt.show()

# %%
# Marcas populares
brands_name = df.brand.value_counts()[:10].index
brand_size = df.brand.value_counts()[:10].values

fig,ax=plt.subplots(figsize=(15,4))
ax.bar(brands_name, brand_size, data=df)
ax.set_ylabel('Nº de produtos')
for p in ax.patches:
    an=ax.annotate(str(p.get_height()), xy=(p.get_x(),p.get_height()))
    an.set_size(12)

# %%
# Ranking das 10 marcas mais populares
top_brands = df.brand.value_counts()[:10].index
filtered_df = df[df['brand'].isin(top_brands)]
brand_stats = filtered_df.groupby('brand')['stars'].agg(['mean', 'count', 'std'])
brand_stats = brand_stats.sort_values('mean', ascending=False).head(10)
brand_stats
# Out:
#                    mean  count       std
# brand
# indomie        4.070755     53  0.954968
# samyang_foods  4.069231     52  0.773466
# paldo          4.018939     66  0.856043
# koka           4.017442     43  0.829865
# nongshim       4.000000     98  0.796254
# nissin         3.918570    381  0.769581
# myojo          3.801587     63  0.812154
# mama           3.703061     98  0.930437
# maruchan       3.554276     76  0.878762
# ottogi         3.393261     46  0.855687

# %%
# Pontuação media no df
df.stars.mean()
# Out:
# 3.654957331264546

# %%
# Pontuação media das 10 marcas principais
brand_stats['mean'].plot(kind='bar', figsize=(10, 6), rot=45)

# Adicionar rótulos e título
plt.title('Média de Estrelas para as 10 Principais Marcas')
plt.xlabel('Marca')
plt.ylabel('Média de Estrelas')
plt.show()

# %%
# Formato do Ramen mais popular 
styles = df['style'].value_counts()
plt.pie(styles[0:4],pctdistance=1.5,autopct="%2.01f%%",radius=1.7,labels= ['pack','bowl','cup','tray'],
        explode=[0,0,0,0.3],
       textprops={'fontsize': 14})
plt.show()

# %%
# Formato mais popular nos Países
a4_dims = (4, 10)
fig, ax = plt.subplots(figsize=a4_dims)
sns.scatterplot(ax= ax, data= df,y= 'country',x= 'style')
plt.show()

# %%
formatos_desejados = ['pack', 'bowl', 'cup', 'tray']
filtered_df = df[df['style'].isin(formatos_desejados)].copy()

# Calcular a nota média apenas para os formatos filtrados
style_mean = filtered_df.groupby('style')['stars'].mean().sort_values(ascending=False)

sns.barplot(x=style_mean.values, y=style_mean.index)

plt.title("Nota média por formato de ramen (pack, bowl, cup, tray)")
plt.xlabel("Média de avaliação")
plt.ylabel("Formato")
plt.show()

# %%
filtered_df.groupby('style')['stars'].mean()
# Out:
# style
# bowl    3.670686
# cup     3.498500
# pack    3.700477
# tray    3.545139
# Name: stars, dtype: float64

# %%
sns.boxplot(data=df, x='style', y='stars')
plt.title("Distribuição das notas por estilo de ramen")
plt.xlabel("Estilo")
plt.ylabel("Nota")
plt.show()

# %%
japan=df.loc[(df['country'] == 'japan') & (df['stars'] >= 4.5)]
usa=df.loc[(df['country'] == 'usa') & (df['stars'] >= 4.5)]
south_korea=df.loc[(df['country'] == 'south_korea') & (df['stars'] >= 4.5)]
fig, axes = plt.subplots(1, 3, figsize=(15, 5), sharey=True)

fig.suptitle('TOP MARCAS DE RAMEN')

axes[0].set_title('TOP 3 MARCAS PREFERIDAS NO JAPÃO',fontsize=10)
axes[1].set_title('TOP 3 MARCAS PREFERIDAS NOS USA',fontsize=10)
axes[2].set_title('TOP 3 MARCAS PREFERIDAS NA COREIA DO SUL',fontsize=10)

# JAPAN
x_jp= japan['brand'].value_counts()
x_jp= x_jp[:3,]
sns.barplot(ax=axes[0],x=x_jp.index, y=x_jp.values,palette="Paired")

# USA
x_usa= usa['brand'].value_counts()
x_usa= x_usa[:3,]
sns.barplot(ax=axes[1],x=x_usa.index,y= x_usa.values,palette="hls")

# SOUTH KOREA
x_sk= south_korea['brand'].value_counts()
x_sk= x_sk[:3,]
sns.barplot(ax=axes[2],x=x_sk.index,y= x_sk.values,palette="Paired")
plt.show()
